# %%
import pandas as pd  # NX2UpxC?.RzST6t

# %%
df = pd.read_csv('survey_results_public.csv',index_col='Respondent') #不用默认的0123 用repsondent的值作为每一行的index，列数减少一个

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info
# Out:
# <bound method DataFrame.info of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_columns',85) # set how many columns will be display

# %%
schema_df = pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc['MgrIdiot'] #直接用列名查询
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True) # ascending=False倒序
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
# to show all rows or the first 20 rows
pd.set_option('display.max_rows',20)

# %%
df['Student']
# Out:
# 0                    No
# 1        Yes, full-time
# 2                    No
# 3                    No
# 4                    No
#               ...
# 88878                No
# 88879               NaN
# 88880               NaN
# 88881               NaN
# 88882    Yes, full-time
# Name: Student, Length: 88883, dtype: object

# %%
type(df['Student'][0])
# Out:
# str

# %%
df['Student'][0].lower()
# Out:
# 'no'

# %%
df.head() #first 5 rows
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail() # last 5 rows
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# 改变 列名
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace = True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes': True,'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True,'No': False})

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.sort_values(by=['Country','SalaryUSD'], ascending=[True,False],inplace=True)

# %%
df[['Country','SalaryUSD']].head(15)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10,'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2e07589c5ceb> in <module>
# ----> 1 df['SalaryUSD'].head(15)
#
# NameError: name 'df' is not defined

# %%
# convert dictionary into dataframe
people = {
    'first':['John','Ethan','Walter'],
    'last':['Smith','Tai','Disney'],
    'email':['john.smith@gmail.com', 'ethantai@gmail.com','walterdisney@gmail.com']
    }
dataframe = pd.DataFrame(people)

dataframe
# Out:
#     first    last                   email
# 0    John   Smith    john.smith@gmail.com
# 1   Ethan     Tai      ethantai@gmail.com
# 2  Walter  Disney  walterdisney@gmail.com

# %%
type(dataframe['email'])  # Series-- 1D array, a row of data with more functions
# Out:
# pandas.core.series.Series

# %%
dataframe.email
# Out:
# 0      john.smith@gmail.com
# 1        ethantai@gmail.com
# 2    walterdisney@gmail.com
# Name: email, dtype: object

# %%
dataframe[['first','last']] #receive a list as parameter, all column names in the list
# Out:
#     first    last
# 0    John   Smith
# 1   Ethan     Tai
# 2  Walter  Disney

# %%
dataframe.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
dataframe.iloc[0] # check specific row, integer location用数字表示位置
# Out:
# first                    John
# last                    Smith
# email    john.smith@gmail.com
# Name: 0, dtype: object

# %%
dataframe.iloc[[0,1]] # select two rows
# Out:
#    first   last                 email
# 0   John  Smith  john.smith@gmail.com
# 1  Ethan    Tai    ethantai@gmail.com

# %%
dataframe.iloc[[0,1],2] # select two rows, the 3rd column
# Out:
# 0    john.smith@gmail.com
# 1      ethantai@gmail.com
# Name: email, dtype: object

# %%
dataframe.loc[0] #loc用label定位，行有index0，1，2，3作为integer用
# Out:
# first                    John
# last                    Smith
# email    john.smith@gmail.com
# Name: 0, dtype: object

# %%
dataframe.loc[[0,1],'email'] #列用名称
# Out:
# 0    john.smith@gmail.com
# 1      ethantai@gmail.com
# Name: email, dtype: object

# %%
dataframe.loc[[0,1],['email','last']] # 顺序Matters
# Out:
#                   email   last
# 0  john.smith@gmail.com  Smith
# 1    ethantai@gmail.com    Tai

# %%
dataframe['first'].value_counts()  #对该列中的数据进行统计
# Out:
# John      1
# Ethan     1
# Walter    1
# Name: first, dtype: int64

# %%
dataframe.loc[0:2,'first':'email']
# Out:
#     first    last                   email
# 0    John   Smith    john.smith@gmail.com
# 1   Ethan     Tai      ethantai@gmail.com
# 2  Walter  Disney  walterdisney@gmail.com

# %%
# use unique column as index in stead of 0,1,2,3..

# %%
dataframe.set_index('email')  # use email as index, 暂时的 不改变原数据结构
# Out:
#                          first    last
# email
# john.smith@gmail.com      John   Smith
# ethantai@gmail.com       Ethan     Tai
# walterdisney@gmail.com  Walter  Disney

# %%
dataframe
# Out:
#     first    last                   email
# 0    John   Smith    john.smith@gmail.com
# 1   Ethan     Tai      ethantai@gmail.com
# 2  Walter  Disney  walterdisney@gmail.com

# %%
dataframe.set_index('email', inplace=True) #改变原数据结构

# %%
dataframe
# Out:
#                          first    last
# email
# john.smith@gmail.com      John   Smith
# ethantai@gmail.com       Ethan     Tai
# walterdisney@gmail.com  Walter  Disney

# %%
dataframe.index
# Out:
# Index(['john.smith@gmail.com', 'ethantai@gmail.com', 'walterdisney@gmail.com'], dtype='object', name='email')

# %%
dataframe.loc['walterdisney@gmail.com']
# Out:
# first    Walter
# last     Disney
# Name: walterdisney@gmail.com, dtype: object

# %%
dataframe.reset_index(inplace=True) # reset

# %%
dataframe
# Out:
#                     email   first    last
# 0    john.smith@gmail.com    John   Smith
# 1      ethantai@gmail.com   Ethan     Tai
# 2  walterdisney@gmail.com  Walter  Disney

# %%
bargain_idx = (reviews.points / reviews.price).idxmax()
bargain_wine = reviews.loc[bargain_idx, 'title']

# %%
grp = df.groupby('Name') 
grp.get_group('subgroup name')

for name,value in grp:
    print(name)
    print(value)
    
grp.agg({'Age' : 'sum', 'Score' : 'std'})
